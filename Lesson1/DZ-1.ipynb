# %% [markdown]
# ## Домашнее задание
#
# 1. Выберите наборы данных. которые можно интерпретировать, как временные ряды:
#
#     а) зависимость цены на недвижимость в еонкретном регионе от времени,
#
#     б) скорость полета самолета при перелете из аэропорта А в аэропорт В,
#
#     в) количество отказов компьютера,
#
#     г) число обращений в поликлинику по району,
#
#     д) координаты автобуса при движении по маршруту,
#
#     е) координаты фигуры нарушителя в файле видеофиксации охранной системы.

# %% [markdown]
# Временные ряды:
# а) зависимость цены на недвижимость в конкретном регионе от времени,
# б) скорость полета самолета при перелете из аэропорта А в аэропорт В,
# д) координаты автобуса при движении по маршруту,
# е) координаты фигуры нарушителя в файле видеофиксации охранной системы.
#
# К не временным рядам относятся:
# в) количество отказов компьютера - т.к. это независимые события не привязанные ко времени.
# г) число обращений в поликлинику по району - не указан временной период, в течении которого будут собираться эти данные.

# %% [markdown]
# 2. Прочитайте DUQ_hourly.csv и проверьте качество и порядок разметки этой выборки с информацией о потреблении энергии в одном из районов Восточной Электросети США. Сделайте описание особенностей этой выборки.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
# Duquesne Light Co. (DUQ).
data_deok = pd.read_csv('DUQ_hourly.csv', index_col=[0], parse_dates=[0])
_ = data_deok.plot( style='.', figsize=( 15, 7 ), title='DUQ ' )

# %%
data_east = pd.read_csv('PJME_hourly.csv', index_col=[0], parse_dates=[0])
data_east.plot( style = '.', figsize = ( 15, 7 ), title = 'PJM East потребление энергии' )
plt.ylabel ( 'МВт' )
# Out:
# Text(0, 0.5, 'МВт')

# %% [markdown]
# Из графического представления можно сделать вывод, что данные DUQ_hourly.csv принадлежат какому-то Южному региону, т.к. PJME_hourly.csv почти в 2 раза выше энергопотребление.

# %% [markdown]
# 3. Прочитайте базу Brent и сделайте ее перерасчет (ресемплинг) в представление по неделям , по месяцам.

# %%
brent_data = pd.read_excel('нефть-brent 2010-2019.xlsx', index_col=[0], parse_dates=[0])

# %%
_ = brent_data['Значение'].plot( style='.', figsize=( 15, 7 ), title='Brent ')
plt.ylabel('USA dollar')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
brent_data_W = brent_data.resample("W").mean()

# %%
brent_data_M = brent_data.resample("M").mean()

# %% [markdown]
# 4. Постройте график изменения среднего по выборке и среднего отклонения по выборке на недельных, месячных и годовых группах для Brent.

# %%
brent_data_W['Значение'].plot( style='.', figsize=( 15, 7 ), title='Brent по неделям ')
plt.ylabel('USA dollar')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %%
brent_data_M['Значение'].plot( style='.', figsize=( 15, 7 ), title='Brent по месяцам ')
plt.ylabel('USA dollar')
plt.xlabel('t')
# Out:
# Text(0.5, 0, 't')

# %% [markdown]
# 5. Сделайте вывод о том, как изменилось поведение цены на недельных и месячных графиках по сравнению с дневными.

# %% [markdown]
# Поведение цены на недельных и месячных графиках по сравнению с дневными практически не изменилось. Предполагаю, что это связанно с тем, что дневные цены берутся усреденением суммы в течении дня, и факторы которые могут повлиять на изменение цены тоже происходят не каждый день.
